# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 15, 13, 18]

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['A', 'B', 'C', 'D']
y = [5, 7, 3, 8]

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.xlabel("X-axis values")
plt.ylabel("Y-axis values")
plt.title("Simple Line Plot")
plt.show()

# %%
x= [1,2,3,4,5]
y= [10,20,30,40,50]
plt.figure(figsize=(10,6), dpi=100)
plt.plot(x, y, color='red', linestyle='-.')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.figure(figsize=(10, 6), dpi=100)
plt.plot(
    x, y,
    color='red',
    ls=':',                  # linestyle
    lw=4,                    # linewidth
    marker='o',
    markerfacecolor='green',
    markersize=8,
    markeredgecolor='black'
)

plt.title("Line Plot Referral", fontsize=16, fontweight='bold', color='blue', loc='left')  # corrected 'la' to 'loc'
plt.xlabel("Years of working", fontsize=12)
plt.ylabel("Profit in Millions", fontsize=12)

plt.grid()
plt.show()

# %%
# Importing necessary libraries
import matplotlib.pyplot as plt   # For plotting
import numpy as np                # Not used in this code, but commonly used for numerical operations

# Data for plotting
x = [1, 2, 3, 4, 5]               # X-axis values (e.g., years)
y = [10, 20, 30, 40, 50]         # Y-axis values (e.g., profit)

# Create a new figure (plot window)
plt.figure(figsize=(10, 6), dpi=100)  # Width=10 inches, Height=6 inches, Dots Per Inch=100

# Plot the line chart
plt.plot(
    x, y,
    color='red',                 # Line color
    ls=':',                      # Line style: ':' means dotted line
    lw=4,                        # Line width
    marker='o',                  # Marker style: 'o' means circle at each data point
    markerfacecolor='green',     # Inside color of the marker
    markersize=8,                # Size of each marker
    markeredgecolor='black'      # Border color of the marker
)

# Set the title of the plot
plt.title(
    "Line Plot Referral",
    fontsize=16,                 # Size of the title font
    ha='left',                   # Align title text to the left
    va='top',                    # Align title to the top vertically
    fontweight='bold',           # Make title text bold
    color='blue'                 # Title text color
)

# Set labels for the X and Y axes
plt.xlabel("Years of working", fontsize=12)       # X-axis label
plt.ylabel("Profit in Millions", fontsize=12)     # Y-axis label

# Set background color of the plot area (where the data is drawn)
plt.gca().set_facecolor('grey')

# Set background color of the entire figure (including margins)
plt.gcf().set_facecolor('brown')

# Add grid lines to the plot
plt.grid(
    True,                        # Enable grid
    linestyle='--',              # Dashed grid lines
    lw=3,                        # Grid line width
    alpha=0.7                    # Transparency of grid lines (0 = fully transparent, 1 = solid)
)

# Display the final plot window
plt.show()

# %%
# Out:
#   Patient_ID    Name   Age  Department Admission_Date      Bill
# 0       P001   Vijay  34.0      Corona     2025-01-15    7000.8
# 1       P002    Ajay  30.0      Cancer     2025-02-10   76000.0
# 2       P003   Kiran   NaN   Neurology     2025-03-03   10000.0
# 3       P004   Amith  60.0  Cardiology     2025-01-22  200000.0
# 4       P005  Suresh  25.0      Cancer     2025-04-06   80000.0
# 5       P006    None  50.0         ICU     2025-05-30       NaN
# Created csv file
# CSV file saved as 'hospital_data.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt
try:
    df=pd.read_csv('hospital_data.csv')
    cost_series= df['Bill']
    date_series= df['Admission_Date']
    print("\n Original Bill series: ")
    print(cost_series)
    print("\n Original Date series: ")
    print(date_series)
# user input for cleaning and plotting
    print('\n Fill the Missing Bill value with median before plotting? (yes/no):')
    fill_confirm = input().strip().lower()
    print("Convert ADMISSION DATE to DD/MM/YYYY for display? (yes/no):")
    date_format_confirm = input().strip().lower()

#perfom clean bill missing values
    if fill_confirm == 'yes':
           median_cost=cost_series.median()
           cleaned_cost_series= cost_series.fillna (median_cost)
           print(cleaned_cost_series)
    else:
           print('\n No changes to medical cost.')
#convert Admission date to datetime
    cleaned_date_series= pd.to_datetime(date_series, format='%Y-%m-%d', errors='coerce')
    if date_format_confirm =='yes':
        display_dates=cleaned_date_series.dt.strftime('%d-%m-%Y')
    else:
        display_dates=cleaned_date_series
#plot
    plt.figure(figsize=(10,6))
    plt.plot(cleaned_date_series, cleaned_cost_series, marker='o', ls='-', color='blue')
    plt.title("Medical Cost Over Admission Dates")
    plt.xlabel("Admission Date")
    plt.ylabel('Medical Cost ($)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
#update and save 
    if fill_confirm == 'yes' or date_format_confirm =='yes':
       df['Bill']= cleaned_cost_series
       df['Admission_date']= display_dates if date_format_confirm == 'yes' else cleaned_date_series
       df.to_csv('hospital_data.csv', index= False)
       print("\n Updated csv saved to 'hospital_data.csv")
    else:
      print('\n Not Updated')
except FileNotFoundError as e:
   print(f'Error : {e}')
except ValueError as e:
   print("Error : Invalid Data format ({e}).")
# Out:
#  Original Bill series:
# 0      7000.8
# 1     76000.0
# 2     10000.0
# 3    200000.0
# 4     80000.0
# 5         NaN
# Name: Bill, dtype: float64
#
#  Original Date series:
# 0    2025-01-15
# 1    2025-02-10
# 2    2025-03-03
# 3    2025-01-22
# 4    2025-04-06
# 5    2025-05-30
# Name: Admission_Date, dtype: object
#
#  Fill the Missing Bill value with median before plotting? (yes/no):
#  yes
# Convert ADMISSION DATE to DD/MM/YYYY for display? (yes/no):
#  yes
# 0      7000.8
# 1     76000.0
# 2     10000.0
# 3    200000.0
# 4     80000.0
# 5     76000.0
# Name: Bill, dtype: float64
#  Updated csv saved to 'hospital_data.csv
